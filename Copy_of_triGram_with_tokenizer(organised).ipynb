# %%
#importing packages
import re
import string
import collections
import math as m

# %%
# !pip install cltk==v0.1.99       #installing cltk
from cltk.tokenize.sentence import TokenizeSentence
tokenizer = TokenizeSentence('telugu')
# Out:
# Requirement already satisfied: cltk==v0.1.99 in /usr/local/lib/python3.11/dist-packages (0.1.99)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (3.1.44)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (3.9.1)
# Requirement already satisfied: python-crfsuite in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (0.9.11)
# Requirement already satisfied: pyuca in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (6.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (2024.11.6)
# Requirement already satisfied: whoosh in /usr/local/lib/python3.11/dist-packages (from cltk==v0.1.99) (2.7.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython->cltk==v0.1.99) (4.0.12)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->cltk==v0.1.99) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->cltk==v0.1.99) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->cltk==v0.1.99) (4.67.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython->cltk==v0.1.99) (5.0.2)

# %% [markdown]
# #loading and converting the train data into a list of sentences
# path='/content/primary_test_data'
# with open(path) as myfile:
#     lines = [line.split('.') for line in myfile.readlines()]

# %% [markdown]
# #loading and converting the test data into a list of sentences
# testpath='/content/test_data'
# with open(testpath) as file:
#     testlines = [line.split('.') for line in file.readlines()]

# %%
path='/content/tewiki_all.txt'
with open(path) as myfile:
    lines = [line.split('. ') for line in myfile.readlines()]
testlines = lines[450000:500000]
lines = lines[:450000]

# %%
#function removing the html tags,punctuations,numbers,english words
def preprocessing_data(str):
    u = re.sub('<[^<]+?>','',str)
    o = re.sub('\u200c',' ',u)
    table = str.maketrans({key: None for key in string.punctuation})
    translated = o.translate(table)
    w = re.sub('[a-zA-Z]*','',translated)
    d = re.sub(' +',' ',w)
    #x = re.sub('[0-9]*','',d)
    y = re.sub("\n",'',d)
    return y

#getting a list of sentences that are clean
def get_preprocessed_sentences(sentences):
    tokenized_sentences=[]
    for i in range(0,len(sentences)):
        temp = []
        for j in range(0,len(sentences[i])):
            final = preprocessing_data(sentences[i][j])
            if len(final) != 0:
                temp.append(final)
        tokenized_sentences.append(temp)
    return tokenized_sentences

train_preprocessed_sentences = get_preprocessed_sentences(lines)
test_preprocessed_sentences = get_preprocessed_sentences(testlines)

# %%
#function to tokenize the sentences
def getting_sentences(line):
    sentences = []
    for i in range(0,len(line)):
        for j in range(0,len(line[i])):
            sentence = line[i][j]
            s = tokenizer.tokenize(sentence)
            sentences.append(s)
    return sentences
train_sentences = getting_sentences(train_preprocessed_sentences)
test_sentences = getting_sentences(test_preprocessed_sentences)

# %%
print("No. of cleaned train sentences " + str(len(train_preprocessed_sentences)))
# Out:
# No. of cleaned train sentences 49285

# %%
# adding start and end delimiter, then splitting
def delimiting_spliting(tokenized_sentences):
    tokenized_sentences = [x for x in tokenized_sentences if x != ['\n'] and x != [' \n']]
    sentences_with_delimiter = []
    for i in range(0,len(tokenized_sentences)):
        s = tokenized_sentences[i]
        if len(s) == 0:
            continue
        temp = ['<s> ']+s+[' </s>']                #adding start and end delimiter
        sentences_with_delimiter.append(temp)
    print(sentences_with_delimiter[:10])
    #split_data =[]
    #for i in range(0,len(sentences_with_delimiter)):
        #d = sentences_with_delimiter[i].split()
        #split_data.append(d)                #spliting the words, and getting the list that contain list of words of every sentence
    return sentences_with_delimiter
split_train_data = delimiting_spliting(train_sentences)
split_test_data = delimiting_spliting(test_sentences)
# Out:
# [['<s> ', 'మొదటి', 'పేజీ', ' </s>'], ['<s> ', 'గుంటూరు', 'జిల్లా', ' </s>'], ['<s> ', 'గుంటూరు', 'జిల్లా', '11391', 'చకిమీ', ' </s>'], ['<s> ', 'ల', 'విస్తీర్ణములో', 'వ్యాపించి', '4889230', '2011', 'గణన', 'జనాభా', 'కలిగిఉన్నది', ' </s>'], ['<s> ', 'ఆగ్నేయాన', 'బంగాళాఖాతము', 'దక్షిణాన', 'ప్రకాశం', 'జిల్లా', 'పశ్చిమాన', 'మహబూబ్', 'నగర్', 'జిల్లా', 'మరియు', 'వాయువ్యాన', 'నల్గొండ', 'జిల్లా', 'సరిహద్దులుగా', 'ఉన్నాయి', ' </s>'], ['<s> ', 'దీని', 'ముఖ్యపట్టణం', 'గుంటూరు', ' </s>'], ['<s> ', 'ఈ', 'జిల్లాకు', 'అతి', 'పురాతన', 'చరిత్ర', 'ఉంది', ' </s>'], ['<s> ', 'మౌర్యులు', 'శాతవాహనులు', 'పల్లవులు', 'చాళుక్యులు', 'కాకతీయులు', 'రెడ్డి', 'రాజులు', 'విజయనగర', 'రాజులు', 'పరిపాలించారు', ' </s>'], ['<s> ', 'పల్నాటి', 'యుద్ధం', 'ఇక్కడే', 'జరిగింది', ' </s>'], ['<s> ', 'మొగలు', 'సామ్రాజ్యం', 'నిజాం', 'పాలన', 'ఈస్ట్', 'ఇండియా', 'కంపెనీ', 'ఆ', 'తరువాత', 'మద్రాసు', 'ప్రసిడెన్సీలో', 'భాగమైనది', ' </s>']]
# []

# %% [markdown]
# #function to tokenize the sentences
# def getting_sentences(line):
#     sentences = []
#     for i in range(0,len(line)):
#         for j in range(0,len(line[i])):
#             sentence = line[i][j]
#             s = tokenizer.tokenize(sentence)
#             sentences.append(s)
#     return sentences
# train_sentences = getting_sentences(lines)
# test_sentences = getting_sentences(testlines)

# %% [markdown]
# #function removing the html tags,punctuations,numbers,english words
# def preprocessing_data(str):
#     u = re.sub('<[^<]+?>','',str)
#     o = re.sub('\u200c',' ',u)
#     table = str.maketrans({key: None for key in string.punctuation})
#     translated = o.translate(table)
#     w = re.sub('[a-zA-Z]*','',translated)
#     d = re.sub(' +',' ',w)
#     x = re.sub('[0-9]*','',d)
#     return x
#
# #getting a list of sentences that are clean
# def get_preprocessed_sentences(sentences):
#     tokenized_sentences=[]
#     for i in range(0,len(sentences)):
#         temp = []
#         for j in range(0,len(sentences[i])):
#             final = preprocessing_data(sentences[i][0])
#             temp.append(final)
#         tokenized_sentences.append(temp)
#     return tokenized_sentences
#
# train_preprocessed_sentences = get_preprocessed_sentences(train_sentences)
# test_preprocessed_sentences = get_preprocessed_sentences(test_sentences)

# %% [markdown]
# # adding start and end delimiter, then spliting
# def delimiting_spliting(tokenized_sentences):
#     tokenized_sentences = [x for x in tokenized_sentences if x != ['\n'] and x != [' \n']]
#     sentences_with_delimiter = []
#     for i in range(0,len(tokenized_sentences)):
#         s = tokenized_sentences[i][0]
#         temp = '<s> '+s+' </s>'                     #adding start and end delimiter
#         sentences_with_delimiter.append(temp)
#     split_data =[]
#     for i in range(0,len(sentences_with_delimiter)):    #spliting the words, and getting the list that contain list of words of every sentence
#         d = sentences_with_delimiter[i].split()
#         split_data.append(d)
#     return split_data
# split_train_data = delimiting_spliting(train_preprocessed_sentences)
# split_test_data = delimiting_spliting(test_preprocessed_sentences)

# %%
print("No. of cleaned train sentences " + str(len(split_train_data)))
print("No. of cleaned test sentences " + str(len(split_test_data)))
# Out:
# No. of cleaned train sentences 75658
# No. of cleaned test sentences 0

# %%
#getting a single list of words
def getting_words_list(split_data):
    list = [item for sublist in split_data for item in sublist]
    return list

# %%
words_train = getting_words_list(split_train_data)      #train data words
words_test = getting_words_list(split_test_data)        #test data words

# %%
unique_words = len(set(words_train))   # getting number of unique words in train data
print("Total number of unique words in train data " + str(unique_words))
# Out:
# Total number of unique words in train data 122388

# %%
#geting the dictionary(model) from the train data, where keys are the history words and values are
#another dictionary which contains keys as the next word and its values corresponding to the number
#of times that words has occurred
dic = {}
for i in range(0,len(words_train)-2):
    t = words_train[i] +'_'+ words_train[i+1]
    s = dic.get(t)
    next = i+2
    if s == None:
        dic[t] = [words_train[next]]
    else:
        s.append(words_train[next])
        temp = {t:s}
        dic.update(temp)
#test_dic is a dictionary where keys are the history words of the test data and values is the list of next words

test_dic = {}
for i in range(0,len(words_test)-2):
    t = words_test[i] +'_'+ words_test[i+1]
    s = test_dic.get(t)
    next = i+2
    if s == None:
        test_dic[t] = [words_test[next]]
    else:
        s.append(words_test[next])
        temp = {t:s}
        test_dic.update(temp)

# %%
# getting the count of each element in the list
def frequency_count(list):
    c = collections.Counter(list)
    count_dic={}
    for i in range(0,len(list)):
        count_dic[list[i]] = c[list[i]]
    return count_dic

# %%
# updating the dic with the word frequency
for word in dic:
    s = dic.get(word)
    value = frequency_count(s)
    temporary = {word:value}
    dic.update(temporary)

# %%
# getting the probability of each predictable word
def get_probability(s1,s2,s3):
    twoWords = s1+'_'+s2
    nextWord = s3
    inner_dic = dic.get(twoWords)
    if inner_dic == None:
        return 0
    else:
        numerator = inner_dic.get(nextWord)
        if numerator == None:
            return 0
        else:
            denominator = sum(inner_dic.values())
            return numerator/denominator

# %%
# getting the add-one probability of each predictable word
def get_addOne_probability(s1,s2,s3):
    twoWords = s1+'_'+s2
    nextWord = s3
    inner_dic = dic.get(twoWords)
    if inner_dic == None:
        return 0
    else:
        numerator = inner_dic.get(nextWord)
        if numerator == None:
            numerator = 1
        else:
            numerator = numerator + 1
        denominator = sum(inner_dic.values()) + unique_words
    return numerator/denominator

# %%
# getting the add-alpha probability of each predictable word
def get_addAlpha_probability(s1,s2,s3):
    twoWords = s1+'_'+s2
    nextWord = s3
    alpha = 0.1
    inner_dic = dic.get(twoWords)
    if inner_dic == None:
        return 0 #alpha/(alpha*unique_words)
    else:
        numerator = inner_dic.get(nextWord)
        if numerator == None:
            numerator = alpha
        else:
            numerator = numerator + alpha
        denominator = sum(inner_dic.values()) + (unique_words*alpha)
    return numerator/denominator

# %%
#preparing probability dictionaries with corresponding probabilities
prob_dic = {}
addOneProb_dic = {}
addAlphaProb_dic = {}
for i in range(0,len(words_test)-3):
    trigram = words_test[i]+'_'+words_test[i+1]+'_'+words_test[i+2]
    prob = get_probability(words_test[i],words_test[i+1],words_test[i+2])
    prob_dic[trigram]=prob
    addOneProb = get_addOne_probability(words_test[i],words_test[i+1],words_test[i+2])
    addOneProb_dic[trigram] = addOneProb
    addAlphaProb = get_addAlpha_probability(words_test[i],words_test[i+1],words_test[i+2])
    addAlphaProb_dic[trigram] = addAlphaProb

# %%
# computing perplexity Score
def perplexityScore(prob_dic):
    logProb = 0
    num = 0
    for word in prob_dic:
        p = prob_dic.get(word)
        if p == 0:
            logProb = logProb
        else:
            w = m.log(p**-1,10)
            logProb = logProb + w
            num = num + 1
    return (2**(logProb/num))

# %%
# perplexity Scores for different cases
ans = perplexityScore(prob_dic)
print(ans)
ans1 = perplexityScore(addOneProb_dic)
print(ans1)
ans2 = perplexityScore(addAlphaProb_dic)
print(ans2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-33-8c4087c70dce> in <cell line: 0>()
#       1 # perplexity Scores for different cases
# ----> 2 ans = perplexityScore(prob_dic)
#       3 print(ans)
#       4 ans1 = perplexityScore(addOneProb_dic)
#       5 print(ans1)
#
# <ipython-input-32-4c9b59a103ab> in perplexityScore(prob_dic)
#      11             logProb = logProb + w
#      12             num = num + 1
# ---> 13     return (2**(logProb/num))
#
# ZeroDivisionError: division by zero

# %%
def getting_3rd(input_word):
    s = dic.get(input_word)
    if s == None:
        print("not found")
        return
    else:
        maximum = max(s, key=s.get)
        return maximum

# %%
#input interface
s1 = input("Enter the 1st word " )
s2 = input("Enter the 2nd word " )
input_word = s1 +'_'+ s2
getting_3rd(input_word)
#printing a sequence of words
i = 1
third = getting_3rd(input_word)
for i in range(1,20):
        print(third)
        s1 = s2
        s2 = third
        input_word = s1 +'_'+ s2
        third = getting_3rd(input_word)
# Out:
# Enter the 1st word వాయవ్య
# Enter the 2nd word అంచున
# గల
# కొండలు
# మల్లవరం
# దగ్గర
# కృష్ణానదిలో
# కలిసేవరకు
# ఉన్నాయి
#  </s>
# <s>
# గ్రామంలో
# మగవారి
# సంఖ్య
# 6377
# ఆడవారి
# సంఖ్య
# 5142
#  </s>
# <s>
# గ్రామంలో

# %%
d వాయవ్య
Enter the 2nd word అంచున

# %%
#input interface
s1 = input("Enter the 1st word " )
s2 = input("Enter the 2nd word " )
input_word = s1 +'_'+ s2
def getting_3rd(input_word):
    s = dic.get(input_word)
    if s == None:
        print("not found")
        return
    else:
        maximum = max(s, key=s.get)
        return maximum
getting_3rd(input_word)
# Out:
# Enter the 1st word వాయవ్య
# Enter the 2nd word అంచున
# 'గల'

# %%
import itertools
out = dict(itertools.islice(dic.items(), 90))
for i in out:
    print(i + ": ",out[i])
# Out:
# <s> _మొదటి:  {'పేజీ': 1, 'కారణం': 1, 'భాషగా': 1, 'బిరుదు': 1, 'దశలో': 3, 'పాదంలో': 1, 'మైక్రోకంప్యూటర్\u200d': 1, 'నుంచీ': 1, 'వాక్యంలో': 1, 'చాళుక్య': 1, 'సమితిని': 1, 'సారి': 3, 'నిజాం': 1, 'బ్లాగు': 1, 'పులకేశి': 1, 'ప్రపంచ': 4, 'స్థానంలో': 5, 'శతాబ్దంలో': 1, '3': 1, 'రెండు': 3, 'ఈస్ట్': 1, 'బాబిలోన్': 1, 'ఇరానియన్': 1, 'సెక్రటరీ': 1, 'ఉజ్బెకిస్థాన్': 1, 'ఆంగ్లబర్మా': 1, 'పారిశ్రామిక': 1, 'చిత్రంలో': 1, 'గుహలోని': 1, 'వాక్యం': 1, 'విక్రమేంద్రవర్మ': 1, 'కుళోత్తుంగచోళుని': 1, 'పరంతక': 1, 'మూడు': 1, 'కొన్ని': 1, 'చింతామణ్రావు': 1, 'ప్రదర్శనకే': 1, 'వివాహం': 1, 'భార్య': 2, 'కూతురు': 1, 'సినిమాగా': 1, 'రామేశ్వర': 1, 'పద్యంలోనే': 1, 'కాలంలో': 1, 'వృచ్చకునికొ': 1, 'మెనాండరు': 1, 'వాసుదేవ': 1, 'ముగ్గురు': 1, 'మహేంద్రవర్మ': 1, 'రాజరాజచోళుడు': 1, 'గోపాలా': 1, 'రాజారజ': 1, 'తారియన్': 1, 'బుక్కరా': 1, 'బాజీరావ్': 1, 'మాధవరావు': 1, 'కుమారుడు': 1, 'బుక్క': 2, 'హరిహర': 1, 'యుద్ధము': 1, 'తరం': 1, 'దేవరాయలు': 2, 'దేవ': 1, 'మూడురాసులును': 1, 'గేయం': 1, 'నాలుగు': 1, 'పుస్తకంలో': 1, 'ప్రత్యేక': 1, 'కార్యక్రమంగా': 1, 'దాడులవలె': 1, 'ప్రాకారంలో': 1, 'సర్పంచిగా': 1, 'ఎన్నికైన': 1, 'ఆలయము': 1, 'కవితా': 1, 'ఉచ్ఛారణ': 1}
# మొదటి_పేజీ:  {' </s>': 1}
# పేజీ_ </s>:  {'<s> ': 48}
#  </s>_<s> :  {'గుంటూరు': 26, 'ల': 3, 'ఆగ్నేయాన': 1, 'దీని': 137, 'ఈ': 2947, 'మౌర్యులు': 2, 'పల్నాటి': 4, 'మొగలు': 5, 'స్వాతంత్ర్య': 12, 'స్వాతంత్ర్యం': 20, 'విద్యా': 11, 'వరి': 251, 'కృష్ణ': 12, 'చంద్రవంక': 3, 'జిల్లా': 191, 'పాత': 18, 'వేంగీ': 1, '1147': 1, 'బౌద్ధం': 1, 'బౌద్ధులు': 3, 'తారనాథుని': 1, 'ప్రసిద్ధ': 7, 'ప్రతీపాలపుర': 1, 'శాసన': 5, 'పూ': 9, '230': 3, 'వివిధ': 51, 'కొందరు': 24, 'అటువంటి': 19, 'జిల్లాలోని': 46, '687లో': 1, 'సామ్రాజ్యపు': 3, 'ఉత్తర': 66
# <s> _గుంటూరు:  {'జిల్లా': 10, 'ప్రాంతంలో': 1, 'ప్రాచీనాంధ్రకాలమునాటి': 1, 'ఛానల్గుంటూరు': 1, 'విజయవాడ': 2, 'జిల్లాలో': 4, 'నుంచి': 2, 'తాలూకా': 1, 'మాచర్ల': 1, 'జిల్లాలోని': 1, 'మున్సిపల్': 1, 'మండలం': 1}
# గుంటూరు_జిల్లా:  {' </s>': 5, '11391': 1, 'సగటున': 1, 'వేమూరు': 1, 'పరిధిలో': 1, 'యొక్క': 1, 'మరియు': 1, 'తూర్పున': 1, 'కవిగా': 1, 'బెల్లంకొండలో': 1, 'కృష్ణా': 1, 'కొల్లూరులో': 1, 'లోని': 6, 'కేంద్ర': 2, 'నరసరావుపేట': 4, 'నరసరావుపేటకు': 1, 'కోటప్పకొండలోని': 1, 'వాయవ్యంలో': 1, 'మైదవోలులో': 1, 'వేల్పూరు': 1, 'ఆనకట్ట': 1, 'తాళ్ళపల్లె': 1, 'నర్సారావుపేట': 1, 'ప్రాంతంలో': 1, 'పరిసర': 1, 'లోనే': 1, 'వినుకొండ': 1, 'నాయకుల': 1, 'బాపట్లలో': 1, 'ఇదే': 3, 'పెనుమూడి': 1, 'మండలం': 1, 'పొగాకు': 1, 'నుంచి': 1, 'రొంపిచెర్ల': 1, 'యడ్లపాడు': 1, 'ఎడిషన్': 1, 'పెదకాకాని': 1, 'కొల్లూరు': 1, 'తుళ్ళూరు': 1, 'గుంటూరు': 1, 'మేడికొండూరుకు': 1, 'ముప్పాళ్ల': 1}
# జిల్లా_ </s>:  {'<s> ': 85}
# జిల్లా_11391:  {'చకిమీ': 1}
# 11391_చకిమీ:  {' </s>': 1}
# చకిమీ_ </s>:  {'<s> ': 45}
# <s> _ల:  {'విస్తీర్ణములో': 1, 'లోతు': 1, 'దూరంలోను': 1}
# ల_విస్తీర్ణములో:  {'వ్యాపించి': 1}
# విస్తీర్ణములో_వ్యాపించి:  {'4889230': 1, 'ఉండేది': 1}
# వ్యాపించి_4889230:  {'2011': 1}
# 4889230_2011:  {'గణన': 1}
# 2011_గణన:  {'జనాభా': 1}
# గణన_జనాభా:  {'కలిగిఉన్నది': 1}
# జనాభా_కలిగిఉన్నది:  {' </s>': 1}
# కలిగిఉన్నది_ </s>:  {'<s> ': 3}
# <s> _ఆగ్నేయాన:  {'బంగాళాఖాతము': 1}
# ఆగ్నేయాన_బంగాళాఖాతము:  {'దక్షిణాన': 1}
# బంగాళాఖాతము_దక్షిణాన:  {'ప్రకాశం': 1}
# దక్షిణాన_ప్రకాశం:  {'జిల్లా': 1}
# ప్రకాశం_జిల్లా:  {'పశ్చిమాన': 1, 'ఏర్పాటు': 1, '1978': 1, ' </s>': 3, 'ఆంధ్ర': 2, 'ముఖ్య': 1, 'గుంటూరు': 1, 'యొక్క': 1, 'కంభం': 3, 'లోని': 3, 'యేర్పాటైన': 1, 'అర్థవీడు': 1, 'బెస్తవారిపేట': 1, 'వేటపాలెం': 1, 'ఉన్ననూ': 1, 'మొత్తం': 1, 'చినగంజాము': 1, 'నల్లమల్ల': 1, 'మద్దిపాడు': 1, 'ఇదే': 14, 'త్రిపురాంతకం': 1, 'కలెక్టరుగారి': 1, 'పెద్దారవీడు': 1, 'తర్లుపాడు': 1, 'దొనకొండ': 1, 'వెలిగండ్ల': 1, 'కేంద్రమైన': 1, 'కలెక్టరు': 1, 'గ్రామము': 1, 'యద్దనపూడి': 1, 'మార్టూరు': 1, 'అద్దంకి': 1, 'నాగులుప్పలపాడు': 1, '1978లో': 1, 'అనే': 1, 'కొమరోలు': 1}
# జిల్లా_పశ్చిమాన:  {'మహబూబ్': 1, 'మరియు': 1, 'అనంతపురం': 1, 'కొండాకోనలతో': 1, 'కర్ణాటకకు': 1}
# పశ్చిమాన_మహబూబ్:  {'నగర్': 1}
# మహబూబ్_నగర్:  {'జిల్లా': 30, 'జిల్లాలో': 14, 'జిల్లాకు': 4, 'జిల్లాలోని': 4, 'జిల్లాలలో': 2, 'మరియు': 2, 'జిల్లాలు': 2, 'జిల్లాల్లో': 3, 'ప్రాంతాన్ని': 2, 'అని': 1, 'ప్రాంతంలో': 1, 'చరిత్రను': 1, 'అనే': 1, 'కు': 1, 'లలో': 1, 'పట్టణంలో': 3, 'స్పెషల్': 1, ' </s>': 1, 'డివిజన్': 2, 'గద్వాల': 2, 'షాద్': 1, 'పట్టణంలోనే': 1, 'మెయిన్': 1, 'టౌన్': 1, 'నుంచి': 2, 'మరికల్': 1, 'స్థానం': 1, 'మండలంలో': 1, 'పట్టణంలోని': 1, 'నల్గొండ': 2, 'జిల్లాల': 2, 'కర్నూలు': 2, 'మెదక్': 3, 'అగ్రస్థానంలో': 1, 'లో': 1, 'కి': 1, 'ప్రకాశం': 1, 'మిర్యాలగూడ': 1, 'కల్వకుర్తి': 1, 'ప్రాంతాలలో': 1, 'బెంగుళూరు': 1, 'తదితర': 1, 'జిల్లాలలోని': 1}
# నగర్_జిల్లా:  {'మరియు': 1, 'లోని': 1, ' </s>': 1, 'తెలంగాణా': 1, 'ను': 1, 'ప్రత్యేకతలు': 1, 'అతి': 1, 'రాష్ట్రంలోనే': 1, 'పరిధిలో': 1, 'జనాభా': 1, 'గుండా': 1, 'కేంద్రంగా': 1, 'ఆలంపూర్లో': 1, 'పెద్దది': 1, 'దక్షిణ': 1, 'అగ్నేయప్రాంతం': 1, 'ఆగ్నేయమున': 1, 'గంగాపురంలోని': 1, 'కొత్తూరు': 1, 'కొత్తూరులో': 1, '4042': 1, 'కోడంగల్': 1, 'ప్రథమ': 1, 'ప్రథమస్థానంలో': 1, 'పశ్చిమాన': 1, 'నుండి': 1, 'తంగడి': 1, 'యొక్క': 1, 'ఉట్నూరు': 1, 'లో': 1, 'జూరాల': 1}
# జిల్లా_మరియు:  {'వాయువ్యాన': 1, 'పశ్చిమాన': 1, 'తూర్పు': 2, 'మహారాష్ట్ర': 1, 'రంగారెడ్డి': 1, '63': 1, 'ఆ': 2, 'పట్టణము': 3, 'పరిసర': 1, 'ఒక': 1, 'గుల్బర్గా': 1, 'రాయచూరు': 1, 'బెంగుళూరు': 1, 'ఈరోడ్': 1, 'నీలిగిరి': 1, 'పట్టణం': 1, 'జిల్లా': 1, 'అదే': 1}
# మరియు_వాయువ్యాన:  {'నల్గొండ': 1}
# వాయువ్యాన_నల్గొండ:  {'జిల్లా': 1}
# నల్గొండ_జిల్లా:  {'సరిహద్దులుగా': 1, ' </s>': 1, 'తెలంగాణా': 1, 'పోరాటాలకు': 1, 'రేఖా': 1, 'పరిధిలో': 1, 'పునర్య్వస్థీకరించారుఅధికారికంగా': 1, 'ఉత్తరమున': 1, 'దేవరకొండలో': 2, 'వాడపల్లి': 1, 'నైరుతి': 1, 'సరిహద్దుగా': 1, 'ఏలేశ్వరంలో': 1, 'మిర్యాలగూడ': 1, 'ఆమనగల్లులో': 1, 'దక్షిణమున': 1, 'ఉన్నాయి': 2, 'రామన్నపేట': 2, 'లో': 1, 'నందికొండ': 1, 'పెద్దవూర': 1, 'ఉత్తరాన': 1, 'వేములపల్లి': 1}
# జిల్లా_సరిహద్దులుగా:  {'ఉన్నాయి': 3, 'ఉన్నవి': 1, 'వాయలూరు': 1}
# సరిహద్దులుగా_ఉన్నాయి:  {' </s>': 19}
# ఉన్నాయి_ </s>:  {'<s> ': 6531}
# <s> _దీని:  {'ముఖ్యపట్టణం': 2, 'వైశాల్యం': 3, 'పర్యవేక్షణలోనే': 1, '“నిల్వ': 1, 'వలన': 4, 'రచయిత': 1, 'ద్వారా': 6, 'మొదటి': 1, 'యందు': 1, 'కాల': 2, 'పైన': 1, 'నుండే': 1, 'మొక్క': 1, 'గింజలను': 1, 'చరిత్ర': 2, 'నుంచి': 1, 'శాస్త్రీయ': 5, 'వల్ల': 4, 'వెనుక': 3, 'ప్రభావము': 1, 'ఉపనది': 1, 'లాంటి': 1, 'ప్రస్తుత': 3, 'స్థాపిత': 1, 'ద్వారానే': 1, 'క్రింద': 2, 'తరువాత': 4, 'నుండి': 4, 'పై': 1, 'మీద': 1, 'మీదుగా': 1, 'పూర్తిపేరు': 1, 'గోడలు': 1, 'పరిసర': 1, 'రాజధాని': 4, 'కొరకు': 1, 'తర్వాత': 3, 'పేరు': 2, 'మొత్తం': 2, 'ప్రకారం': 6, 'కోసం': 2, 'ఎత్తు': 1, 'ఎగువ': 1, 'వ్యాప్తిని': 1, 'జన్మస్థానం': 1, 'గ్రామరు': 1, 'పర్యవసానంగా': 1, 'చుట్టుకొలత': 2, 'వయసు': 1, 'మధ్య': 1, 'అసలు': 1, 'అధికార': 2, 'పాలకులైన': 1, 'ఆదాయం': 1, 'ఫలితంగా': 5, 'పొడవు': 2, 'విజయంతో': 1, 'ఇతివృత్తం': 1, 'ప్రధాన': 2, 'ఉపనదుల్లో': 1, 'ధర': 1, 'కూర': 1, 'శిధిలాలు': 1, 'కాయలు': 1, 'సాధారణముగా': 1, 'నివేదికపై': 2, 'అధ్యక్షులు': 1, 'ముఖ్య': 1, 'పరిధి': 2, 'పాతపేరు': 1, 'అక్షాంశ': 2, 'నిర్మాణము': 2, 'నిర్మాణ': 2, 'చుట్టూ': 1, 'పనుండి': 1, 'ఉపశీర్షిక': 1, 'గురించిన': 1, 'విచారణకై': 1, 'దగియెడు': 1, 'పూర్వనామము': 1}
# దీని_ముఖ్యపట్టణం:  {'గుంటూరు': 1, 'ఆదిలాబాద్బీజాపూర్': 1}
# ముఖ్యపట్టణం_గుంటూరు:  {' </s>': 1}
# గుంటూరు_ </s>:  {'<s> ': 4}
# <s> _ఈ:  {'జిల్లాకు': 9, 'సామంతుల': 1, 'జిల్లాలో': 23, 'రాష్ట్రంలోని': 1, 'విధంగా': 26, 'పట్టణము': 11, 'క్రింది': 11, 'రోజుల్లో': 16, 'ఉపకరణాన్ని': 1, 'సొంత': 2, 'సమాచారాన్ని': 3, 'సమాచారం': 1, 'ప్రోగ్రామర్లు': 1, 'మాటని': 1, 'క్రమణికలు': 1, 'క్రమణికలని': 1, 'రకం': 5, '“ప్రోసెస్”': 1, 'వివరాలన్నీ': 1, 'ద్వితీయ': 1, 'ప్రోసెసర్': 1, 'ప్రక్రియ': 2, 'కర్మరి': 1, 'కొట్టు': 2, '“బస్”': 1, 'మూడు': 9, 'నిరవాకి': 4, 'అనువర్తనాలు': 1, 'పనులన్నీ': 1, 'బయాస్': 1, 'పని': 6, 'ప్రోగ్రాములు': 2, 'ప్రోగ్రాములన్నిటిని': 1, 'రూపకల్పన': 1, 'నిర్మాణము': 1, 'భాగములనన్నిటిని': 1, 'క్రమణికలో': 1, 'శాల్తీ': 1, 'సున్నలని': 1, 'వివరణ': 2, 'సందర్భంలో': 5, 'చితుకు': 2, 'చితుకులో': 1, 'ట్రాన్సిస్టర్ల': 1, 'బప్ఫర్': 1, 'తీగ': 1, 'ఒక్క': 1, 'విభాగములో': 2, 'సమాచారము': 1, 'విభాగము': 1, 'విధముగా': 5, 'బోధనలో': 1, 'సిలబసు': 1, 'ఊరగాయను': 1, 'మధ్య': 6, 'నూనె': 1, 'పద్యం': 6, 'పచ్చళ్ళు': 1, 'రెండు': 29, 'పట్టీలకు': 1, 'పరిశోధనల': 2, 'పరిస్థితి': 4, 'వ్యత్యాసాలని': 1, 'రెండింటి': 3, 'ప్రవర్తనకి': 1, 'విషయాన్నే': 1, 'కుటుంబములో': 1, 'ప్రాకృతానికి': 1, 'విధమైన': 5, 'మాత్రల': 1, 'కాలంలో': 48, 'వ్యాధులకు': 1, 'వ్యాధికి': 1, 'ఆటలో': 2, 'ఆట': 4, 'ఆటను': 2, 'వరుసనే': 1, 'యగంలో': 2, 'కాలాన్నే': 1, 'వేగిదేశమునకు': 1, 'వేగిపురమును': 1, 'వేగిదేశ': 1, 'అన్యాయాన్ని': 1, 'యల్లాడమంత్రి': 1, 'సింగన్న': 1, 'తిక్కన': 1, 'కవి': 3, 'విషయమై': 7, 'రచన': 2, 'హరివంశం': 1, 'రచనలో': 1, 'శేషభాగాన్ని': 1, 'ప్రాంతమునకు': 2, 'కావ్యమును': 1, 'కాలమందు': 1, 'చాట
ాన్సర్': 1, 'రకపు': 2, 'రకము': 6, 'కాయపైననే': 1, 'పురుగు': 1, 'పురుగుపట్టి': 1, 'వైరసును': 1, 'తెగులు': 1, 'మొక్క': 1, 'విషయంలో': 3, 'సంస్థకు': 1, 'పంటకు': 2, 'బంగాళదుంప': 1, 'మొక్కలు': 3, 'పద్ధతిన': 1, 'దిగుబడిలో': 1, 'స్టార్చి': 1, 'జీర్ణం': 1, 'భూమి': 3, 'ప్రక్తియ': 1, 'చిరుఫలాలన్నీ': 1, 'బరువు': 1, 'బరువులో': 1, 'అరటి': 1, 'పద్ధతిలో': 2, 'విలువలు': 1, 'వ్యాధి': 1, 'బిగ్': 1, 'మెట్లు': 1, 'గుర్తులు': 1, 'ఆలయగర్భగుడిలో': 1, 'డిపోలో': 1, 'పుణ్యక్షేత్రం': 2, 'ఆలయంలోని': 5, 'మహిమ': 1, 'కొబ్బరి': 1, 'రోజుకి': 1, 'గ్రామములో': 30, 'గ్రామం': 20, 'పట్టణం': 22, 'దేవాలయము': 6, 'క్షేత్రమునకు': 1, 'గోపురాన్ని': 1, 'గోపురం': 1, 'కూలిపోవడానికి': 1, 'దేవాలయం': 11, 'గోపుర': 2, 'గోపురంనుండి': 1, 'నాగరూపమునే': 1, 'నాగరూపం': 1, 'క్లబ్': 1, 'ఉత్సవం': 2, 'రద్దీని': 1, 'తొమ్మిది': 2, 'ఉత్సవాల': 1, 'ఉత్సవాలలో': 8, 'వామనావతార': 1, 'పొట్టి': 1, 'కథలో': 1, 'క్రిందివే': 1, 'ద్వీపము': 1, 'ద్వీపంలో': 1, 'వృక్షాలు' ...
# ఈ_జిల్లాకు:  {'అతి': 1, '1982': 1, 'వైవిధ్యాన్ని': 1, 'విదేశీ': 1, 'చెందినవారు': 1, 'ఇచ్చిన': 1, 'చెందినవారే': 3, 'హిరణ్యదేశంని': 1, 'చెందిన': 2, 'తూర్పున': 2, 'పేరు': 1, 'ప్రధాన': 1, 'దక్షిణంగా': 1, 'మహబూబ్': 1, 'కూడా': 1, 'నామకరణము': 1, 'పశ్చిమాన': 1, 'వాయవ్యసరిహద్దులో': 1, 'ఉత్తరాన': 1, 'వాయువ్యాన': 1, 'ఈ': 1}
# జిల్లాకు_అతి:  {'పురాతన': 1, 'సమీపంలోని': 1, 'సమీపంలో': 1}
# అతి_పురాతన:  {'చరిత్ర': 1, 'నౌకా': 1, 'ప్రాంతం': 1, 'కీసరగుట్ట': 1, 'వేదసాహిత్యం': 1, 'కాలంలో': 1}
# పురాతన_చరిత్ర:  {'ఉంది': 1, 'గురించిన': 1}
# చరిత్ర_ఉంది:  {' </s>': 19, 'ఉయ్యలవాడ': 1}
# ఉంది_ </s>:  {'<s> ': 6839}
# <s> _మౌర్యులు:  {'శాతవాహనులు': 2}
# మౌర్యులు_శాతవాహనులు:  {'పల్లవులు': 1, 'బాదామి': 1, 'తూర్పు': 1, 'ఇక్ష్వాకుల': 1}
# శాతవాహనులు_పల్లవులు:  {'చాళుక్యులు': 1, 'తెలుగు': 1}
# పల్లవులు_చాళుక్యులు:  {'కాకతీయులు': 1, 'చోళులు': 1, 'మరియు': 1}
# చాళుక్యులు_కాకతీయులు:  {'రెడ్డి': 2, 'రాచర్ల': 1, 'విజయనగరరాజులు': 1, 'విజయనగర': 1}
# కాకతీయులు_రెడ్డి:  {'రాజులు': 4}
# రెడ్డి_రాజులు:  {'విజయనగర': 5, 'గజపతులు': 1, 'మొదట': 1, 'పాలించారు': 1, 'తమ': 1, 'వారిని': 1, 'కుతుబ్': 1, 'చక్కని': 1, 'ఉదయగిరి': 1, '13531448': 1, 'ఆలయ': 1}
# రాజులు_విజయనగర:  {'రాజులు': 4, 'ప్రభువులు': 1}
# విజయనగర_రాజులు:  {'పరిపాలించారు': 1, 'మరియు': 1, 'శివాజీ': 1, 'శ్రీవారికి': 1, 'గోల్కొండ': 2, 'ఈ': 1, 'గండికోట': 1, 'డిచ్': 1, 'అవృతఖానాను': 1, 'మొదట్లో': 1, 'కట్టించిన': 1, 'దీనిని': 1, 'పాలించారు': 1, 'పునరుద్ధరించారు': 1, 'మెరుగులు': 1, 'ధార్వాడ': 1, 'చోళులు': 1, 'త్రవ్వించిన': 1, 'పొత్తపి': 1, 'పాలించినట్లు': 1}
# రాజులు_పరిపాలించారు:  {' </s>': 2, 'కాబట్టి': 1}
# పరిపాలించారు_ </s>:  {'<s> ': 39}
# <s> _పల్నాటి:  {'యుద్ధం': 1, 'వీర': 1, 'యుద్ధంలో': 1, 'యుద్ధానికి': 1}
# పల్నాటి_యుద్ధం:  {'ఇక్కడే': 1, 'లాంటి': 1, ' </s>': 1, 'అప్పటి': 1, 'బొబ్బిలి': 1}
# యుద్ధం_ఇక్కడే:  {'జరిగింది': 1}
# ఇక్కడే_జరిగింది:  {' </s>': 1}
# జరిగింది_ </s>:  {'<s> ': 234}
# <s> _మొగలు:  {'సామ్రాజ్యం': 1, 'చక్రవర్తి': 2, 'చక్రవర్తిఔరంగజేబు': 1, 'సైన్యం': 1}
# మొగలు_సామ్రాజ్యం:  {'నిజాం': 1}
# సామ్రాజ్యం_నిజాం:  {'పాలన': 1}
# నిజాం_పాలన:  {'ఈస్ట్': 1, 'కాలంలో': 1, 'వ్యతిరేక': 1, 'నుంచి': 1, 'క్రీశ': 1, 'మీదికి': 1}
# పాలన_ఈస్ట్:  {'ఇండియా': 1}
# ఈస్ట్_ఇండియా:  {'కంపెనీ': 13, 'కంపెనీలో': 1, 'కంపెనీపై': 1, 'కంపెని': 1, 'కంపెనీని': 1, 'కంపెనీకి': 2, 'కంపెనీచే': 1}
# ఇండియా_కంపెనీ:  {'ఆ': 1, 'ఏలుబడి': 1, 'క్రమంగా': 1, 'కొరకు': 1, 'వారి': 1, 'ముఖ్య': 1, 'దీనిని': 1, 'పుణెలోని': 1, 'వారు': 1, 'పెన్షనర్లుగా': 1, 'బెంగాలు': 3, 'భారత': 1, 'పాలనకి': 1, 'స్నేహపూర్వక': 1, 'నుండి': 1, 'కోరమండల్': 1, 'కాలంలో': 1}
# కంపెనీ_ఆ:  {'తరువాత': 1}
శాటన': 1, 'పీఠాధిపతి': 1, 'సదాశివ': 1, 'సుల్తాను': 1, 'బ్రిటిషు': 1, 'దాని': 1, 'ఇది': 1, 'రెండవ': 1, 'ప్రపంచం': 1, 'ట్రేడ్': 1, '1913నుండి': 1, 'మాదిగలు': 1, 'రంగా': 1, '1978': 1, 'అధికారములోకి': 1, 'వెనువెంటనే': 1, 'చాలా': 1, '1973లో': 1}
# తరువాత_మద్రాసు:  {'ప్రసిడెన్సీలో': 1, 'క్రిస్టియన్': 1}
# మద్రాసు_ప్రసిడెన్సీలో:  {'భాగమైనది': 1}
# ప్రసిడెన్సీలో_భాగమైనది:  {' </s>': 1}
# భాగమైనది_ </s>:  {'<s> ': 4}
# <s> _స్వాతంత్ర్య:  {'సమరంలో': 2, 'సమరయోధుడు': 3, 'పోరాట': 2, 'సమర': 2, 'సమరయోధునిగా': 1, 'ఉద్యమ': 1, 'సాధనలో': 1}
# స్వాతంత్ర్య_సమరంలో:  {'పెదనందిపాడు': 1, 'ప్రత్యేక': 1, 'పాల్గొన్నారు': 1, 'పాల్గొనేందుకు': 1}
# సమరంలో_పెదనందిపాడు:  {'పన్నుల': 1}
# పెదనందిపాడు_పన్నుల:  {'ఎగవేత': 1}
# పన్నుల_ఎగవేత:  {'సైమన్': 1}
# ఎగవేత_సైమన్:  {'కమిషన్': 1}
# సైమన్_కమిషన్:  {'వుద్యమం': 1, 'భారతదేశాన్ని': 1}
# కమిషన్_వుద్యమం:  {'లాంటి': 1}
# వుద్యమం_లాంటి:  {'ఎన్నో': 1}
# లాంటి_ఎన్నో:  {'చారిత్రక': 1}
# ఎన్నో_చారిత్రక:  {'ఘట్టాల': 1}
# చారిత్రక_ఘట్టాల:  {'ఈ': 1}
# ఘట్టాల_ఈ:  {'జిల్లాలో': 1}
# ఈ_జిల్లాలో:  {'జరిగాయి': 1, 'ప్రధాన': 3, 'అధిక': 1, 'జరిగిన': 1, 'ఉన్నాయికాకతీయుల': 1, 'కలపబడ్డాయినాలుగు': 1, '19971998': 1, 'పరిశ్రమలకు': 1, '2209': 1, 'ఉంది': 1, 'పురుషుల': 1, '3': 1, 'విస్తారంగా': 2, 'ఉన్న': 7, 'ఈ': 1, 'ఉన్నాయి': 3, 'జోగిపేట': 1, 'వర్షపాతము': 1, '12వ': 1, 'ఈశాన్య': 1, 'చమురు': 1, 'రాజమండ్రి': 1, 'కలిసినవి': 2, 'అతి': 1, 'పలు': 2, '52': 1, 'ప్రధానమైన': 1, 'తెలంగాణలో': 1, '1553': 1, '26': 1, '37': 1, 'ప్రవహించే': 1, 'గ్రామీణ': 1, '5': 1, 'ఆగ్నేయం': 1, 'మొత్తం': 1, 'లేనప్పటికీ': 1, 'ప్రముఖ': 1, 'అనేక': 1, 'సొసివురు': 1, 'భద్ర': 1, 'ఇనుము': 1, 'ఉచ్చస్థితిలో': 1, 'ప్రాంతంలో': 1, 'ముఖ్యమైన': 1, 'అక్కల్': 1, 'కలిపి': 1}
# జిల్లాలో_జరిగాయి:  {' </s>': 1}
